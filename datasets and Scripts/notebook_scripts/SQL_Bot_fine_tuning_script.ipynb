# %%
import json

file = []
with open("/content/dataset.jsonl", "r") as f:
    for line in f:
        line = line.strip()
        if line:
            try:
                json_obj = json.loads(line)
                file.append(json_obj)
            except json.JSONDecodeError as e:
                # Log or handle lines that are not valid JSON if necessary
                print(f"Skipping invalid JSON line: {line} - Error: {e}")

# Assuming the original intent was to access the second JSON object if multiple exist
# If the file contains only one object or an array, this needs to be adjusted.
if len(file) > 1:
    print(file[3])
elif len(file) == 1:
    print(file[0]) # If only one object is found, print it
else:
    print("No JSON objects found in the file.")
# Out:
# {'prompt': 'How to create a table in MySQL for storing user data?', 'completion': 'CREATE TABLE users (id INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(100), email VARCHAR(100), created_at TIMESTAMP);'}

# %%
# !pip uninstall -y unsloth peft
# !pip install unsloth trl peft accelerate bitsandbytes
# Out:
# WARNING: Skipping unsloth as it is not installed.
# Found existing installation: peft 0.18.0
# Uninstalling peft-0.18.0:
#   Successfully uninstalled peft-0.18.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.7/358.7 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 556.4/556.4 kB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.4/284.4 kB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 16.2 MB/s eta 0:00:00
# ...

# %%
from unsloth import FastLanguageModel
import torch, transformers

print("Torch:", torch.__version__)
print("Transformers:", transformers.__version__)
print("Unsloth loaded successfully!")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Torch: 2.9.0+cu126
# Transformers: 4.57.2
# Unsloth loaded successfully!

# %%
# !pip show unsloth peft trl accelerate bitsandbytes torch transformers
# !pip freeze | grep -E "unsloth|peft|trl|accelerate|bitsandbytes|torch|transformers"
# Out:
# accelerate==1.12.0
# bitsandbytes==0.48.2
# fastrlock==0.8.3
# peft==0.18.0
# sentence-transformers==5.1.2
# torch==2.9.0+cu126
# torchao==0.14.1
# torchaudio==2.9.0+cu126
# torchdata==0.11.0
# torchsummary==1.5.1
# torchtune==0.6.1
# torchvision==0.24.0+cu126
# transformers==4.57.2
# trl==0.24.0
# unsloth==2025.11.4
# unsloth_zoo==2025.11.5

# %%
# For GPU check
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
from unsloth import FastLanguageModel
import torch

model_name = "unsloth/Phi-3-mini-4k-instruct-bnb-4bit"

max_seq_length = 1024  # Choose sequence length
dtype = None  # Auto detection

# Load model and tokenizer
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=True,
)
# Out:
# ==((====))==  Unsloth 2025.11.4: Fast Mistral patching. Transformers: 4.57.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/458 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
from datasets import Dataset

def format_prompt(example):
    return f"### Input: {example['prompt']}\n### Output: {example['completion']}<|endoftext|>"

formatted_data = [format_prompt(item) for item in file]
dataset = Dataset.from_dict({"text": formatted_data})

# %%
# Add LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r=64,  # LoRA rank - higher = more capacity, more memory
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=128,  # LoRA scaling factor (usually 2x rank)
    lora_dropout=0,  # Supports any, but = 0 is optimized
    bias="none",     # Supports any, but = "none" is optimized
    use_gradient_checkpointing="unsloth",  # Unsloth's optimized version
    random_state=3407,
    use_rslora=False,  # Rank stabilized LoRA
    loftq_config=None, # LoftQ
)
# Out:
# Unsloth 2025.11.4 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

# Training arguments optimized for Unsloth
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=1024,   # reduces token load massively
    dataset_num_proc=2,
    args=TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=2,
        warmup_steps=5,
        num_train_epochs=1,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=25,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        save_strategy="epoch",
        save_total_limit=2,
        dataloader_pin_memory=False,
        report_to="none",
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/11171 [00:00<?, ? examples/s]

# %%
# Train the model
trainer_stats = trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 11,171 | Num Epochs = 1 | Total steps = 1,397
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 119,537,664 of 3,940,617,216 (3.03% trained)
#     <div>
#
#       <progress value='1397' max='1397' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1397/1397 27:35, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.169100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.759800</td>
#     </tr>
#     <tr>
#       <td>75</td>
# ...

# %%
# Test the fine-tuned model
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# Test prompt
messages = [
    {"role": "user", "content": "delete duplicate enteries in table from 2 different columns"},
]

inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt",
).to("cuda")

# Generate response
outputs = model.generate(
    input_ids=inputs,
    max_new_tokens=256,
    use_cache=True,
    temperature=0.7,
    do_sample=True,
    top_p=0.9,
)

# Decode and print
response = tokenizer.batch_decode(outputs)[0]
print(response)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# <|user|> delete duplicate enteries in table from 2 different columns<|end|><|assistant|> DELETE t1 FROM table t1 JOIN table t2 ON t1.col = t2.col AND t1.id > t2.id;<|end|>

# %%
# FAST & SAFE DOWNLOAD — ONLY LoRA ADAPTER (250–400 MB) → NO CRASH GUARANTEED

from google.colab import files
import os

# 1. Save only the LoRA adapter (super small)
save_dir = "/content/phi3-mini-lora-only"
model.save_pretrained(save_dir)
tokenizer.save_pretrained(save_dir)

# 2. Zip it immediately (very fast because it's tiny)
# !zip -r -q /content/phi3-mini-lora-only.zip {save_dir}

# 3. Download instantly — this file is tiny, Colab will NOT crash
print("Downloading your fine-tuned LoRA adapter (~300 MB max)...")
files.download('/content/phi3-mini-lora-only.zip')

print("DONE! Download started — safe, fast, and session will stay alive.")
# Out:
# ...
# DONE! Download started — safe, fast, and session will stay alive.

# %%
# # CELL 10 – SAFE & FAST GGUF EXPORT (works on free Colab T4 every time)

# # 1. Install/upgrade the very latest Unsloth + pre-compiled llama.cpp (CUDA)
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps xformers trl peft accelerate bitsandbytes
# !pip install -q llama-cpp-python --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu124

# # 2. Import again (in case the kernel reloaded the package)
# from unsloth import FastLanguageModel

# # 3. Convert straight to q4_k_m GGUF – the newest Unsloth versions do it with very low RAM
# #    (no more compilation, no more 15 GB spikes)
# model.save_pretrained_gguf(
#     "gguf_model",                    # folder name
#     tokenizer,                       # your tokenizer from cell 4
#     quantization_method = "q4_k_m"   # best speed/quality for Phi-3-mini
# )

# print("GGUF conversion finished! File is in /content/gguf_model/")

# %%
# # CELL 11 – DOWNLOAD
# import os
# from google.colab import files

# # Find the .gguf file
# gguf_files = [f for f in os.listdir("gguf_model") if f.endswith(".gguf")]
# if not gguf_files:
#     print("No .gguf file found – something went wrong in Cell 10")
# else:
#     filepath = os.path.join("gguf_model", gguf_files[0])
#     size_gb = os.path.getsize(filepath) / (1024**3)
#     print(f"Ready → {gguf_files[0]} ({size_gb:.2f} GB)")
#     files.download(filepath)
